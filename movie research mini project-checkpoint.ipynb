# %% [markdown]
# # MINI EDX RESEARCH PROJECT
#
# ## What are *good* movies without books?
#
#
#
# This notebook uses
# data from the MovieLens website. Im going to explore this dataset mostly using pandas and matplotlib
#
# * **Data Source:** MovieLens web site (filename: ml-20m.zip)
# * **Location:** https://grouplens.org/datasets/movielens/

# %% [markdown]
# # **INFO?** :
# I'd like to explore the effect the book industry has on the movie industry, some questions id like to answer include: what % of top movies overall are based on books? in each genre, what % of top rated movies are based on books? whats the average rating of movies based on books?

# %% [markdown]
# *The first step is to import necessary libraries and explore the data to know whats in the folders and clean up the data.*

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#Using pandas to read the csv file 
Movies = pd.read_csv('./movielens/movies.csv', sep =',')        
print (type(Movies))
Movies.head()                                                   #shows top 5 entrys in the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
Ratings = pd.read_csv('./movielens/ratings.csv', sep = ',') #Sheet with data on ratings, corresponds with Movies on Movie ID
Ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %%
Tags = pd.read_csv('./movielens/tags.csv', sep = ',')#Tags which include descriptions of the movie, based on a book is a tag
Tags.head(10)
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %% [markdown]
# **HOW MANY ENTRIES ARE IN ALL 3?**

# %%
print ('Movies ' + str(len(Movies)),
       'Ratings ' + str(len(Ratings)),
       'Tags ' + str(len(Tags))
      )
# Out:
# Movies 27278 Ratings 20000263 Tags 465564

# %% [markdown]
# **HOW CLEAN IS THE DATA? ARE THERE ANY MISSING VALUES?**

# %%
#Checking for Null/missing values
Movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
Ratings.isnull().any()
# Out:
# userId       False
# movieId      False
# rating       False
# timestamp    False
# dtype: bool

# %%
Tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag           True
# timestamp    False
# dtype: bool

# %%
Tags = Tags.dropna()  #Pandas function to drop null rows

# %%
Tags.isnull().any()   #all clear
# Out:
# userId       False
# movieId      False
# tag          False
# timestamp    False
# dtype: bool

# %% [markdown]
# **CHECKING DESCRIPTIVE STATISTICS TO SEE IF RATING NUMBERS MAKE SENSE**
#
# The range is supposed to be between 0 to 5 stars

# %%
#Only interested in the ratings column 
Ratings['rating'].describe() #Returns information on the data in the 'rating' column in the 'Ratings' data frame
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
#Checking min and max values in the data 

print (Ratings['rating'].min())
print (Ratings['rating'].max())
# Out:
# 0.5
# 5.0

# %% [markdown]
# **Based on these stats, the min is 0.5, max is 5, mean is about 3.5 and the standard deviations looks normal ~ 1.05 from the mean**
#
# Exploration continues :)

# %%
 del Tags['timestamp']
 del Tags['userId'] 
#Removing information i dont need
Tags.head()
#tagnames = Tags['tag']
#tagnames.to_csv("Test.csv")
# Out:
#    movieId            tag
# 0     4141    Mark Waters
# 1      208      dark hero
# 2      353      dark hero
# 3      521  noir thriller
# 4      592      dark hero

# %%
#Tagsgroup = Tags[['movieId','tag']] .groupby('movieId')  
#type(Tagsgroup)
#Tagsgroup.head()
#I was initially trying to see if i could filter the tags by each movie i'd but then I realised that wasnt a good data move. It limits each movie to only one tag per movie

# %%
del Ratings['timestamp']

# %%
Ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
tag_counts = Tags['tag'].value_counts() 
toptags = tag_counts[:50]      # top 50 tags 
toptags
  # toptags.to_csv("tagnames.csv") - I needed to export the top tags to a csv file to make a word cloud for my presentation
# Out:
# sci-fi                3384
# based on a book       3281
# atmospheric           2917
# comedy                2779
# action                2657
# surreal               2427
# BD-R                  2334
# twist ending          2323
# funny                 2072
# dystopia              1991
# stylized              1941
# quirky                1906
# dark comedy           1899
# classic               1769
# psychology            1754
# fantasy               1703
# time travel           1549
# romance               1534
# visually appealing    1509
# disturbing            1487
# aliens                1428
# thought-provoking     1422
# social commentary     1417
# Nudity (Topless)      1400
# violence              1336
# drugs                 1312
# Criterion             1286
# true story            1276
# nudity (topless)      1245
# adventure             1243
# animation             1229
# imdb top 250          1218
# space                 1199
# CLV                   1199
# dark                  1194
# superhero             1171
# black comedy          1126
# post-apocalyptic      1116
# World War II          1116
# Betamax               1093
# cult film             1080
# satire                1068
# tense                 1032
# thriller              1026
# drama                 1010
# predictable           1008
# politics              1000
# adapted from:book      991
# bittersweet            989
# horror                 983
# Name: tag, dtype: int64

# %%
#plot top movie tags,
# discovered later that one movie can have the same tag multiple times so the number of tags isnt representative of the quantity of movies with that tag 
tag_counts[:10].plot(kind = 'bar', figsize = (15,10))

# %% [markdown]
# # we can see that there are a lot of tags for movies based on books

# %% [markdown]
# # Im going to merge 3 data sets, Movies, their average ratings and their tags then I'll delete unnecessary columns

# %%
avgratings= Ratings.groupby('movieId', as_index = False).mean()  # grouping info on each movie and finding the average rating for each movie 
del avgratings['userId'] # dont need the user id, I want the code to run as quickly as possible so Im deleting info I dont need
avgratings.head()
# Out:
#    movieId    rating
# 0        1  3.921240
# 1        2  3.211977
# 2        3  3.151040
# 3        4  2.861393
# 4        5  3.064592

# %%
#Merging movies with thier rating using their unique movie id
Movieratings = Movies.merge(avgratings, on = 'movieId', how = 'inner')


Movieratings.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.921240
# 1                   Adventure|Children|Fantasy  3.211977
# 2                               Comedy|Romance  3.151040
# 3                         Comedy|Drama|Romance  2.861393
# 4                                       Comedy  3.064592
# 5                        Action|Crime|Thriller  3.834930
# 6                               Comedy|Romance  3.366484
# 7                           Adventure|Children  3.142049
# 8                                       Action  3.004924
# 9                    Action|Adventure|Thriller  3.430029

# %%
#I'm only interested in top rated movies so I'm checking how many movies are rated higher than 4 

is_highly_rated = Movieratings['rating'] >= 4   #Creating a filtered dataframe with ratings higher than or equal to 4
highly_rated= Movieratings[is_highly_rated]
print ('The number of movies rated an average score of 4 or more is ' + str(len(highly_rated))) 
highly_rated.sort_values('rating', ascending = False )
# Out:
# The number of movies rated an average score of 4 or more is 1757
#        movieId                                              title  \
# 16952    86055        Foster Brothers, The (Süt kardesler) (1976)
# 23282   111546  Paying the Price: Killing the Children of Iraq...
# 26331   129036                          People of the Wind (1976)
# 20606   101292                                   Abendland (2011)
# 24570   117418  Victor and the Secret of Crocodile Mansion (2012)
# 23824   113860                        Codes of Gender, The (2010)
# 24360   116227                                  Taxi Blues (1990)
# 26421   129526                           The Color of Milk (2004)
# 24821   118610                               Rock the Boat (1944)
# 9557     27914  Hijacking Catastrophe: 9/11, Fear & the Sellin...
# 26423   129530                           Slingshot Hip Hop (2008)
# 14406    72235     Between the Devil and the Deep Blue Sea (1995)
# 18980    94737                       Boys Diving, Honolulu (1901)
# 19971    98761  Shaolin Temple 2: Kids from Shaolin (Shao Lin ...
# 23046   110419                Palestine Is Still the Issue (2003)
# 23843   113947                           Lady of Chance, A (1928)
# 21415   104317    Flight of the Conchords: A Texan Odyssey (2006)
# 18629    92956                            Little Criminals (1995)
# 21005   102882                                 Dream Demon (1988)
# 24547   117314                          Neurons to Nirvana (2013)
# 25936   126945                                 Small Roads (2011)
# 22859   109715                              Inquire Within (2012)
# 19031    94949                               Boy Meets Boy (2008)
# 18597    92783                             Latin Music USA (2009)
# 19040    94972                 Best of Ernie and Bert, The (1988)
# 26358   129305                               Pretty Things (2001)
# 23860   114011                New Rulers of the World, The (2001)
# 21840   105841                                      B-Side (2013)
# 21842   105846                               Only Daughter (2013)
# 18964    94657                    Turkish Dance, Ella Lola (1898)
# ...        ...                                                ...
# 15573    79402                 Telstar: The Joe Meek Story (2008)
# 15912    80792                               Southbounders (2005)
# 15719    80004                          Gaby: A True Story (1987)
# 22312   107625                                      Gorko! (2013)
# 22317   107636                             Springsteen & I (2013)
# 15901    80744  Deciduous Tree (Tree Without Leaves) (Rakuyôju...
# 15804    80337                                  Still Bill (2009)
# 22350   107725                       Botany of Desire, The (2009)
# 15792    80285                                    Conquest (1937)
# 22360   107754                               Soundbreaker (2012)
# 22372   107836                          Annie Get Your Gun (1967)
# 15788    80269                            Above and Beyond (1952)
# 22397   107903                                       Stars (1959)
# 15772    80210                         End of Poverty, The (2008)
# 22417   107974                       Bride Comes Home, The (1935)
# 15680    79844  Battle of the Rails, The (La bataille du rail)...
# 22518   108403                   Rock-afire Explosion, The (2008)
# 22441   108056                             Pokémon Origins (2013)
# 22443   108065     Comrade Pedersen (Gymnaslærer Pedersen) (2006)
# 22455   108100       Honest Man: The Life of R. Budd Dwyer (2010)
# 15645    79692                              Bjarnfreðarson (2009)
# 22471   108160                   Breakaway (Speedy Singhs) (2011)
# 22476   108194       47  Ronin (Shijûshichinin no shikaku) (1994)
# 15578    79458  Man Who Left His Will on Film, The (Tôkyô sens...
# 22498   108267                                L'antisémite (2012)
# 22507   108316                              American Scary (2006)
# 22512   108342     Monkey in Winter, A (Un singe en hiver) (1962)
# 22516   108395            Why Not Me? (Pourquoi pas moi ?) (1999)
# 22517   108401                                        Husk (2011)
# 26743   131262                                   Innocence (2014)
#
#                            genres  rating
# 16952                      Comedy     5.0
# 23282                 Documentary     5.0
# 26331                 Documentary     5.0
# 20606                 Documentary     5.0
# 24570  Adventure|Children|Mystery     5.0
# 23824                 Documentary     5.0
# 24360                       Drama     5.0
# 26421                Comedy|Drama     5.0
# 24821                   Animation     5.0
# 9557                  Documentary     5.0
# 26423          (no genres listed)     5.0
# 14406                       Drama     5.0
# 18980                 Documentary     5.0
# 19971               Action|Comedy     5.0
# 23046                 Documentary     5.0
# 23843        Comedy|Drama|Romance     5.0
# 21415                      Comedy     5.0
# 18629                 Crime|Drama     5.0
# 21005                      Horror     5.0
# 24547                 Documentary     5.0
# 25936          (no genres listed)     5.0
# 22859                      Comedy     5.0
# 19031                     Romance     5.0
# 18597         Documentary|Musical     5.0
# 19040                    Children     5.0
# 26358                       Drama     5.0
# 23860                 Documentary     5.0
# 21840              Comedy|Romance     5.0
# 21842                       Drama     5.0
# 18964          (no genres listed)     5.0
# ...                           ...     ...
# 15573                Comedy|Drama     4.0
# 15912                       Drama     4.0
# 15719               Drama|Romance     4.0
# 22312                      Comedy     4.0
# 22317                 Documentary     4.0
# 15901                       Drama     4.0
# 15804                 Documentary     4.0
# 22350                 Documentary     4.0
# 15792               Drama|Romance     4.0
# 22360                 Documentary     4.0
# 22372              Comedy|Musical     4.0
# 15788                Action|Drama     4.0
# 22397                   Drama|War     4.0
# 15772                 Documentary     4.0
# 22417              Comedy|Romance     4.0
# 15680                   Drama|War     4.0
# 22518                 Documentary     4.0
# 22441         Adventure|Animation     4.0
# 22443                       Drama     4.0
# 22455                 Documentary     4.0
# 15645                Comedy|Drama     4.0
# 22471                Comedy|Drama     4.0
# 22476                Action|Drama     4.0
# 15578                       Drama     4.0
# 22498                      Comedy     4.0
# 22507   Comedy|Documentary|Horror     4.0
# 22512                Comedy|Drama     4.0
# 22516                      Comedy     4.0
# 22517             Horror|Thriller     4.0
# 26743    Adventure|Fantasy|Horror     4.0
#
# [1757 rows x 4 columns]

# %% [markdown]
# **CONVERTED THIS TO A MARKDOWN BECAUSE I DONT NEED THIS GRAPH BUT I WANT TO BE ABLE TO REFERENCE IT WHEN IM DOING OTHER GRAPHS**
#
# #plot top rated movies and thier ratings
# mtitle = highly_rated['title'].head(10)
# mrating= highly_rated['rating'].head(10)
# y_pos = np.arange(len(mtitle))
#
# plt.figure(figsize = (10,5))
# plt.ylim(4,5)
# plt.bar(mtitle, mrating, alpha= 0.8, color ='g')
#
# plt.xticks(y_pos, mtitle, rotation = 60)
# plt.title('highly rated movies')
# plt.xlabel('movie titiles')
# plt.show()

# %%
Movieinfo = highly_rated.merge(Tags, on= 'movieId', how = 'inner').sort_values('rating', ascending = False) # it didnt let me do this before the rating filter, I think because of the size 
Movieinfo.head(10)
# Out:
#        movieId                                   title               genres  \
# 71541    92783                  Latin Music USA (2009)  Documentary|Musical
# 73821   110419     Palestine Is Still the Issue (2003)          Documentary
# 72993   106517          De la servitude moderne (2009)          Documentary
# 73034   107252                    Island at War (2004)            Drama|War
# 73035   107252                    Island at War (2004)            Drama|War
# 74296   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74295   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74294   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74293   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74292   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
#
#        rating                     tag
# 71541     5.0                    jazz
# 73821     5.0                  Israel
# 72993     5.0    Jean-François Brient
# 73034     5.0             Peter Lydon
# 73035     5.0     Thaddeus O'Sullivan
# 74296     5.0  Everything is Terrible
# 74295     5.0                 strange
# 74294     5.0            mind-melting
# 74293     5.0            mind-bending
# 74292     5.0                 hi Nic!

# %%
#Checking how the tags have changed after the merges 
tag_count2= Movieinfo['tag'].value_counts()
tag_count2[:50]
# Out:
# twist ending            1091
# atmospheric             1043
# classic                  909
# psychology               863
# surreal                  792
# imdb top 250             782
# sci-fi                   755
# fantasy                  660
# thought-provoking        654
# dark comedy              590
# disturbing               568
# stylized                 526
# based on a book          496
# violence                 492
# nonlinear                481
# quirky                   459
# World War II             439
# Quentin Tarantino        436
# social commentary        417
# adventure                391
# action                   387
# space                    386
# black and white          380
# dark                     355
# dystopia                 351
# cult film                339
# Oscar (Best Picture)     338
# dreamlike                331
# comedy                   330
# war                      314
# bittersweet              305
# drama                    304
# visually appealing       300
# psychological            299
# crime                    299
# serial killer            296
# organized crime          295
# Brad Pitt                294
# anime                    290
# romance                  286
# mental illness           286
# suspense                 285
# tense                    283
# black comedy             274
# violent                  267
# great soundtrack         266
# alternate reality        266
# Studio Ghibli            258
# Harrison Ford            249
# Kevin Spacey             246
# Name: tag, dtype: int64

# %%
BasedBook = Movieinfo['tag'].str.contains( 'book' )   #checks if books is in tags 
bookmovie = Movieinfo[BasedBook]
no_of_books = len(bookmovie.title.unique())
print (no_of_books)
b = bookmovie.title.unique()
b
# Out:
# 94
# array(['Going Down in LA-LA Land (2011)', 'Ella Lola, a la Trilby (1898)',
#        'Living Proof (2008)', 'Shawshank Redemption, The (1994)',
#        'Godfather, The (1972)', 'Mahabharata, The (1989)',
#        "Schindler's List (1993)", 'Band of Brothers (2001)',
#        "One Flew Over the Cuckoo's Nest (1975)",
#        'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#        'Third Man, The (1949)', 'City of God (Cidade de Deus) (2002)',
#        'Paths of Glory (1957)', 'Fight Club (1999)',
#        'Double Indemnity (1944)', 'Dark Knight, The (2008)',
#        'Big Sleep, The (1946)',
#        'I Have Found It (Kandukondain Kandukondain) (2000)',
#        'Star Wars: Episode IV - A New Hope (1977)',
#        'To Kill a Mockingbird (1962)', 'Maltese Falcon, The (1941)',
#        'Matrix, The (1999)', 'Goodfellas (1990)',
#        'Silence of the Lambs, The (1991)', 'Princess Bride, The (1987)',
#        'Rashomon (Rashômon) (1950)', 'Pulp Fiction (1994)',
#        'Forsyte Saga, The (1967)', 'Vertigo (1958)',
#        'Witness for the Prosecution (1957)',
#        'Lord of the Rings: The Return of the King, The (2003)',
#        'Song of the Little Road (Pather Panchali) (1955)',
#        'Lord of the Rings: The Fellowship of the Ring, The (2001)',
#        'Blade Runner (1982)', 'Manchurian Candidate, The (1962)',
#        'Don Quixote (1933)', 'Drained (O cheiro do Ralo) (2006)',
#        'Sanjuro (Tsubaki Sanjûrô) (1962)', 'Rebecca (1940)',
#        'Laura (1944)', 'Bleak House (2005)',
#        'Bridge on the River Kwai, The (1957)', 'Apocalypse Now (1979)',
#        'Lord of the Rings: The Two Towers, The (2002)',
#        'Professional, The (Le professionnel) (1981)',
#        'African Queen, The (1951)',
#        'High and Low (Tengoku to jigoku) (1963)',
#        'Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)',
#        'Manon of the Spring (Manon des sources) (1986)', 'Psycho (1960)',
#        'Dersu Uzala (1975)', 'Kind Hearts and Coronets (1949)',
#        "Howl's Moving Castle (Hauru no ugoku shiro) (2004)",
#        'Anatomy of a Murder (1959)',
#        'Maltese Falcon, The (a.k.a. Dangerous Female) (1931)',
#        'Persuasion (1995)', 'Seven (a.k.a. Se7en) (1995)',
#        'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)',
#        'Secret in Their Eyes, The (El secreto de sus ojos) (2009)',
#        'North & South (2004)', 'Prestige, The (2006)',
#        'Man Who Would Be King, The (1975)',
#        "All the President's Men (1976)",
#        "Pan's Labyrinth (Laberinto del fauno, El) (2006)",
#        'To Have and Have Not (1944)', 'Requiem for a Dream (2000)',
#        'Full Metal Jacket (1987)', 'Bourne Identity, The (1988)',
#        'Unvanquished, The (Aparajito) (1957)',
#        'Christmas Story, A (1983)', 'To Catch a Thief (1955)',
#        'Forrest Gump (1994)',
#        'In the Mood For Love (Fa yeung nin wa) (2000)', 'Stalker (1979)',
#        'Seven Days in May (1964)', 'Pride and Prejudice (1995)',
#        'Shining, The (1980)', 'Trainspotting (1996)',
#        'Let the Right One In (Låt den rätte komma in) (2008)',
#        'Crumb (1994)', 'Woman in the Dunes (Suna no onna) (1964)',
#        'Grapes of Wrath, The (1940)', 'Sweet Hereafter, The (1997)',
#        '39 Steps, The (1935)', 'How to Train Your Dragon (2010)',
#        'Dark Knight Rises, The (2012)',
#        'Human Capital (Il capitale umano) (2013)', 'Tracks (2013)',
#        'Grant Morrison: Talking with Gods (2010)',
#        'First Man, The (Le Premier Homme) (2011)',
#        'Promised Land (Ziemia Obiecana) (1975)',
#        'Time to Kill (Tempo di uccidere) (1989)',
#        'Twilight People, The (1973)', 'Straight from the Heart (2003)'],
#       dtype=object)

# %%
#Whats the average rating of highly rated book  movies, and highly rated movies in general ?
#average rating of books in highly rated list 
avrating = bookmovie['rating'].mean()
print (avrating)
# Out:
# 4.152882423777357

# %%
#what % of top movies is books?
percentage = float(round((no_of_books/len(highly_rated)) * 100, 2))
print ('the percentage of top movies based on books is ' + str(percentage) + '%' )
# Out:
# the percentage of top movies based on books is 5.35%

# %% [markdown]
# # This is much lower than i expected!

# %% [markdown]
# ## Maybe movies based on books are more  popular in certain genres? I'm going to check the differences in drama, romance, thrillers, animations, comedy genres

# %%
Movieinfo.head(10)
# Out:
#        movieId                                   title               genres  \
# 71541    92783                  Latin Music USA (2009)  Documentary|Musical
# 73821   110419     Palestine Is Still the Issue (2003)          Documentary
# 72993   106517          De la servitude moderne (2009)          Documentary
# 73034   107252                    Island at War (2004)            Drama|War
# 73035   107252                    Island at War (2004)            Drama|War
# 74296   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74295   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74294   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74293   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
# 74292   120134  Doggiewoggiez! Poochiewoochiez! (2012)               Comedy
#
#        rating                     tag
# 71541     5.0                    jazz
# 73821     5.0                  Israel
# 72993     5.0    Jean-François Brient
# 73034     5.0             Peter Lydon
# 73035     5.0     Thaddeus O'Sullivan
# 74296     5.0  Everything is Terrible
# 74295     5.0                 strange
# 74294     5.0            mind-melting
# 74293     5.0            mind-bending
# 74292     5.0                 hi Nic!

# %%
# Movieinfo['genres'].unique() # looking through the tags to see what the genres are like

# %% [markdown]
# ## I'm going to check the top rated movies and see which genres have top movies based on books

# %% [markdown]
# ## Horror

# %%
horror= Movieinfo['genres'].str.contains('Horror' )    #filtering out horror movies
Horror = Movieinfo[horror]

no_of_horror_movies = len(Horror.title.unique())          #getting the no of horror movies & avoiding duplicates
print('There are ' + str(no_of_horror_movies) + ' horror movies')

horrorbooks= Horror['tag'].str.contains('book')
Horrorbooks = Horror[horrorbooks]

no_of_horrorbooks = len(Horrorbooks.title.unique())
print ('There are ' + str(no_of_horrorbooks) +  'horror movies based on books')

horrorpercentage = float(round((no_of_horrorbooks/no_of_horror_movies) * 100, 2))
print ('the percentage of top horror movies based on books is ' + str(horrorpercentage) + '%')
# Out:
# There are 28 horror movies
# There are 5horror movies based on books
# the percentage of top horror movies based on books is 17.86%

# %% [markdown]
# ## Drama

# %%
drama= Movieinfo['genres'].str.contains('Drama')
Drama = Movieinfo[drama]

no_of_drama_movies = len(Drama.title.unique())
print('There are ' + str(no_of_drama_movies) + ' top rated drama movies')
# print(Drama.title.unique()) < -- for cross checking results 


dramabooks= Drama['tag'].str.contains('book')
Dramabooks = Drama[dramabooks]

# print (Dramabooks.title.unique())

no_of_dramabooks = len(Dramabooks.title.unique())
print ('There are ' + str(no_of_dramabooks) +  ' drama movies based on books')

dramapercentage = float(round((no_of_dramabooks/no_of_drama_movies) * 100, 2))
print ('the percentage of top drama movies based on books is ' + str(dramapercentage) + '%')
# Out:
# There are 572 top rated drama movies
# There are 65 drama movies based on books
# the percentage of top drama movies based on books is 11.36%

# %% [markdown]
# ## Romance

# %%
romance= Movieinfo['genres'].str.contains('Romance')
Romance = Movieinfo[romance]

no_of_romance_movies = len(Romance.title.unique())
print('There are ' + str(no_of_romance_movies) + ' top rated romance movies')


romancebooks= Romance['tag'].str.contains('book')
Romancebooks = Romance[romancebooks]

no_of_romancebooks = len(Romancebooks.title.unique())
print ('There are ' + str(no_of_romancebooks) +  ' romance movies based on books')

romancepercentage = float(round((no_of_romancebooks/no_of_romance_movies) * 100, 2))
print ('the percentage of top romance movies based on books is ' + str(romancepercentage) + '%')
# Out:
# There are 143 top rated romance movies
# There are 17 romance movies based on books
# the percentage of top romance movies based on books is 11.89%

# %% [markdown]
# ## Adventure

# %%
adventure= Movieinfo['genres'].str.contains('Adventure')
Adventure = Movieinfo[adventure]
                                           
no_of_adventure_movies = len(Adventure.title.unique())
print('There are ' + str(no_of_adventure_movies) + ' top rated adventure movies')


adventurebooks= Adventure['tag'].str.contains('book')
Adventurebooks = Adventure[adventurebooks]

no_of_adventurebooks = len(Adventurebooks.title.unique())
print ('There are ' + str(no_of_adventurebooks) +  ' adventure movies based on books')

adventurepercentage = float(round((no_of_adventurebooks/no_of_adventure_movies) * 100, 2))
print ('the percentage of top adventure movies based on books is ' + str(adventurepercentage) + '%')
# Out:
# There are 80 top rated adventure movies
# There are 20 adventure movies based on books
# the percentage of top adventure movies based on books is 25.0%

# %% [markdown]
# ## Crime

# %%
crime= Movieinfo['genres'].str.contains('Crime')
Crime = Movieinfo[crime]
                                           
no_of_crime_movies = len(Crime.title.unique())
print('There are ' + str(no_of_crime_movies) + ' top rated crime movies')


crimebooks= Crime['tag'].str.contains('book')
Crimebooks = Crime[crimebooks]

no_of_crimebooks = len(Crimebooks.title.unique())
print ('There are ' + str(no_of_crimebooks) +  ' crime movies based on books')

crimepercentage = float(round((no_of_crimebooks/no_of_crime_movies) * 100, 2))
print ('the percentage of top crime movies based on books is ' + str(crimepercentage) + '%')
# Out:
# There are 100 top rated crime movies
# There are 20 crime movies based on books
# the percentage of top crime movies based on books is 20.0%

# %% [markdown]
# ## Action

# %%
action= Movieinfo['genres'].str.contains('Action')
Action = Movieinfo[action]
                                           
no_of_action_movies = len(Action.title.unique())
print('There are ' + str(no_of_action_movies) + ' top rated action movies')


actionbooks= Action['tag'].str.contains('book')
Actionbooks = Action[actionbooks]

no_of_actionbooks = len(Actionbooks.title.unique())
print ('There are ' + str(no_of_actionbooks) +  ' action movies based on books')

actionpercentage = float(round((no_of_actionbooks/no_of_action_movies) * 100, 2))
print ('the percentage of top action movies based on books is ' + str(actionpercentage) + '%')
# Out:
# There are 85 top rated action movies
# There are 17 action movies based on books
# the percentage of top action movies based on books is 20.0%

# %% [markdown]
# ## Sci-Fi

# %%
scify= Movieinfo['genres'].str.contains('Sci')
Scify = Movieinfo[scify]
                                           
no_of_scify_movies = len(Scify.title.unique())
print('There are ' + str(no_of_scify_movies) + ' top rated scify movies')


scifybooks= Scify['tag'].str.contains('book')
Scifybooks = Scify[scifybooks]

no_of_scifybooks = len(Scifybooks.title.unique())
print ('There are ' + str(no_of_scifybooks) +  ' Sci-fy movies based on books')

scifypercentage = float(round((no_of_scifybooks/no_of_scify_movies) * 100, 2))
print ('the percentage of top Sci-fy movies based on books is ' + str(scifypercentage) + '%')
# Out:
# There are 39 top rated scify movies
# There are 6 Sci-fy movies based on books
# the percentage of top Sci-fy movies based on books is 15.38%

# %% [markdown]
# ## Comedy

# %%
comedy= Movieinfo['genres'].str.contains('Comedy')
Comedy = Movieinfo[comedy]
                                           
no_of_comedy_movies = len(Comedy.title.unique())
print('There are ' + str(no_of_comedy_movies) + ' top rated comedy movies')


comedybooks= Comedy['tag'].str.contains('book')
Comedybooks = Comedy[comedybooks]

no_of_comedybooks = len(Comedybooks.title.unique())
print ('There are ' + str(no_of_comedybooks) +  ' Comedy movies based on books')

comedypercentage = float(round((no_of_comedybooks/no_of_comedy_movies) * 100, 2))
print ('the percentage of top Comedy movies based on books is ' + str(comedypercentage) + '%')
# Out:
# There are 243 top rated comedy movies
# There are 12 Comedy movies based on books
# the percentage of top Comedy movies based on books is 4.94%

# %%
#importing seaborn for visualisation
import seaborn as sns

# %%
#To plot the graph of all the genres, I found it easiest to extract them into a new dataframe I've just called data
data= [['Comedy', comedypercentage ],['Drama', dramapercentage],['Romance',romancepercentage],['Sci-fy', scifypercentage],
       ['Horror', horrorpercentage],['Action', actionpercentage],['Crime', crimepercentage] , ['Adventure', adventurepercentage] ]

df = pd.DataFrame(data, columns = ['Genres', '% of top rated movies based on books'])   #creating a pandas dataframe so i can plot the data on a chart
df
# Out:
#       Genres  % of top rated movies based on books
# 0     Comedy                                  4.94
# 1      Drama                                 11.36
# 2    Romance                                 11.89
# 3     Sci-fy                                 15.38
# 4     Horror                                 17.86
# 5     Action                                 20.00
# 6      Crime                                 20.00
# 7  Adventure                                 25.00

# %%
sns.set_style('darkgrid')  #set style is used to set the background for the graph
sns.barplot(x ='% of top rated movies based on books', y = 'Genres', data = df )  #barplot is the command for creating a bar chart

# %% [markdown]
# # Conclusion
#
# We can see that while the overall average of top rated movies based on bools is 5.35% in certain genres the percentages are much higher. **Adventure** has the highest percentage of top rated book-based movies, followed by Crime & Action.
#
# I guess if youre an author and want a film adaptation made of your book then its better to write a reaaalllyyy good action, crime or adventure one. or if you'd like to be the exception write a really cute romance book, I mean if Nicolas Sparks could do it with The Note book and Jojo Moyes with Me before you then you can try your luck.
#
# It's probably best not to write a comedy with the aim of it being adapted for a movie.
